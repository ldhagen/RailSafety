# %% [markdown]
# https://safetydata.fra.dot.gov/Output/1529504152951101.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline

# %%
rail__2022_df = pd.read_csv('https://safetydata.fra.dot.gov/Output/1529504152951101.csv')

# %%
rail__2022_df.describe()
# Out:
#                IYR  INCDTNO        IYR2  INCDTNO2         IYR3  INCDTNO3  \
# count  2186.000000    165.0  165.000000    2186.0  2186.000000       0.0
# mean      5.965691     22.0    5.654545      22.0     5.965691       NaN
# std       3.155934      0.0    2.968646       0.0     3.155934       NaN
# min       1.000000     22.0    1.000000      22.0     1.000000       NaN
# 25%       3.000000     22.0    3.000000      22.0     3.000000       NaN
# 50%       6.000000     22.0    5.000000      22.0     6.000000       NaN
# 75%       9.000000     22.0    8.000000      22.0     9.000000       NaN
# max      11.000000     22.0   11.000000      22.0    11.000000       NaN
#
#          GXID         YEAR        MONTH          DAY  ...       COUNTY  \
# count  2186.0  2186.000000  2186.000000  2186.000000  ...  2186.000000
# mean     22.0     5.965691    15.608875     6.358188  ...    97.021958
# std       0.0     3.155934     8.910503     3.447583  ...    99.611977
# ...

# %%
rail__2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2186 entries, 22 to 22
# Columns: 145 entries, IYR to SUBDIV
# dtypes: float64(32), int64(60), object(53)
# memory usage: 2.4+ MB

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
for x in rail__2022_df.columns:
    print(x)
# Out:
# IYR
# IMO
# RAILROAD
# INCDTNO
# IYR2
# IMO2
# RR2
# INCDTNO2
# IYR3
# IMO3
# RR3
# INCDTNO3
# DUMMY1
# GXID
# YEAR
# MONTH
# DAY
# TIMEHR
# TIMEMIN
# AMPM
# TYPE
# CARS
# CARSDMG
# CARSHZD
# EVACUATE
# DIVISION
# STATION
# MILEPOST
# STATE
# TEMP
# VISIBLTY
# WEATHER
# TRNSPD
# TYPSPD
# TRNNBR
# TRNDIR
# TONS
# TYPEQ
# EQATT
# TRKNAME
# TRKCLAS
# TRKDNSTY
# TYPTRK
# RRCAR1
# CARNBR1
# POSITON1
# LOADED1
# RRCAR2
# CARNBR2
# POSITON2
# LOADED2
# HEADEND1
# MIDMAN1
# MIDREM1
# RMAN1
# RREM1
# HEADEND2
# MIDMAN2
# MIDREM2
# RMAN2
# RREM2
# LOADF1
# LOADP1
# EMPTYF1
# EMPTYP1
# CABOOSE1
# LOADF2
# LOADP2
# EMPTYF2
# EMPTYP2
# CABOOSE2
# EQPDMG
# TRKDMG
# CAUSE
# CAUSE2
# CASKLDRR
# CASINJRR
# CASKLD
# CASINJ
# ACCAUSE
# ACCTRK
# ACCTRKCL
# HIGHSPD
# ACCDMG
# DUMMY2
# STCNTY
# TOTINJ
# DUMMY3
# TOTKLD
# ENGRS
# FIREMEN
# CONDUCTR
# BRAKEMEN
# ENGHR
# ENGMIN
# CDTRHR
# CDTRMIN
# JOINTCD
# REGION
# DUMMY4
# TYPRR
# DUMMY5
# RRDIV
# METHOD
# NARRLEN
# DUMMY6
# YEAR4
# RREMPKLD
# RREMPINJ
# ...

# %%
    rail__2022_df['NARR1']
# Out:
# 22    DING THEIR TRAIN THE CREW UNKNOWINGLY RAN THRO...
# 22    THE EMPLOYEE STATES HE WAS IN POSITION ON THE ...
# 22    THE EMPLOYEE STATES HE WAS IN POSITION ON THE ...
# 22    TRAIN IN EMERGENCY CREW DERAILED THE 91ST CAR ...
# 22    CK, WHEN GOT A DRAWBAR SHOVING IN. CREW DIDN'T...
# 22    CUT THAT WAS BEING SHOVED WESTWARD INTO BOWL 4...
# 22    CUT THAT WAS BEING SHOVED WESTWARD INTO BOWL 4...
# 22                       D THE SET OF TRUCKS TO DERAIL.
# 22    SES OR INJURIES. **BNSF REPORTED $28,000 IN TR...
# 22    ILED 26’ EAST OF ATC STATION MARKER H1988 ON T...
# 22    YARD. CONDUCTOR GAVE IMPROPER CAR COUNT DUE TO...
# 22    PIECE OF WIRE BETWEEN ENGINE 4504 AND 5353 AND...
# 22                                                  NaN
# 22    IS STILL UNDER INVESTIGATION. NO HAZMAT WAS RE...
# 22    ARDER PULL AND WAS DRAGGING DOWN AND THEN WENT...
# 22    ANCE IN THE TRAIN. HE IMMEDIATELY TOOK ACTION ...
# 22                                                  NaN
# ...

# %%
rail__2022_df[rail__2022_df['NARR5'].str.contains('HAZMAT', na = False)][['NARR5']]
# Out:
#                                                 NARR5
# 22  VER FROM THE FORCE AND CAME TO REST ON CARS IN...
# 22  VER FROM THE FORCE AND CAME TO REST ON CARS IN...
# 22  D NON-HAZMAT WASTE OIL CAR. NON HAZMAT WASTE O...
# 22  ACED UNDER THE DRIP AND HAZMAT MANAGER WAS CON...
# 22     NT. THERE WERE NO INJURIES OR HAZMAT INVOLVED.

# %%
rail__2022_df.iloc[0]['SSB2']
# Out:
# 'KYLE CREW WAS BUILDING AN INBOUND MANIFEST TRAIN IN THE SALINA UP YARD. WHILE IN THE PROCESS OF BUIL'

# %%
rail__2022_df.iloc[0]['NARR1']
# Out:
# 'DING THEIR TRAIN THE CREW UNKNOWINGLY RAN THROUGH A SWITCH. AS THE TRAIN DEPARTED THE SIXTEENTH (16)'

# %%
rail__2022_df.iloc[0]['NARR2']
# Out:
# 'CAR FROM THE HEADEND OF THE TRAIN DERAILED AT THE PREVIOUS RUN THROUGH SWITCH. THE DERAILED CAR STA'

# %%
rail__2022_df.iloc[0]['NARR3']
# Out:
# 'YED UPRIGHT AND WAS DRAGGED APPROXIMATELY ONE-HALF MILE BEFORE IMPACTING AN UNATTENDED LOCOMOTIVE. O'

# %%
rail__2022_df.iloc[0]['NARR4']
# Out:
# 'NCE IMPACTING THE UNATTENDED LOCOMOTIVE, THE DERAILED CAR TIPPED OVER ON ITS SIDE ALSO DERAILING THE'

# %%
rail__2022_df.iloc[0]['NARR5']
# Out:
# 'FIFTEENTH (15) CAR FROM THE HEAD END. WITH THE SECOND IMPACT TO THE UNATTENDED LOCOMOTIVE THE COUPL'

# %%
rail__2022_df.iloc[0]['NARR6']
# Out:
# 'ERS BYPASSED CAUSING THE RAIL TO ROLL UNDER AND DERAIL THE SEVENTEENTH (17) CAR OF THEIR TRAIN.'

# %%
rail__2022_df.iloc[0]['NARR7']
# Out:
# nan
